# %% [markdown]
# <a href="https://colab.research.google.com/github/JananiC/Module_1/blob/main/C1_W1_Lab01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello, Janani!")
# Out:
# Hello, Janani!

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x_train = np.array([1.0, 2.0])
y_train = np.array([300.0, 500.0])
print(f"x_train = {x_train}")
print(f"y_train = {y_train}")
# Out:
# x_train = [1. 2.]
# y_train = [300. 500.]

# %%
print(f"x_train.shape = {x_train.shape}")
m = x_train.shape[0]
print(f"Number of training examples is {m}")
# Out:
# x_train.shape = (2,)
# Number of training examples is 2

# %%
m = len(x_train)
print(f"Number of training examples is {m}")
# Out:
# Number of training examples is 2

# %%
i = 0 # Change this to 1 to see (x^1, y^1)

x_i = x_train[i]
y_i = y_train[i]
print(f"(x^({i}), y^({i})) = ({x_i}, {y_i})")
# Out:
# (x^(0), y^(0)) = (1.0, 300.0)

# %%
#plot the data points
plt.scatter(x_train, y_train, marker='o',c='r')
# Set the title
plt.title("Housing Prices")
# Set the y-axis label
plt.ylabel('Price (in 1000s of dollars)')
# Set the x-axis label
plt.xlabel('Size (1000 sqft)')
plt.show()

# %%
w = 200
b = 100
print(f"w = {w}")
print(f"b = {b}")
# Out:
# w = 200
# b = 100

# %%
def compute_model_output(x, w, b):
  '''
  x is ndarray which is a n-dimensional array in Numpy of size m
  w, b are model parameters
  '''
  m = x.shape[0]
  #f_wb is the target variable one dimensional array initiyalized with zero
  f_wb = np.zeros(m)
  print(f"printing np zeros array : f_wb initial values {f_wb}")
  for i in range(m):
    f_wb[i] = w * x[i] + b

  return f_wb

# %%
tmp_f_wb = compute_model_output(x_train, w, b)
print(f"tmp_f_wb : {tmp_f_wb}")
plt.scatter(x_train, y_train, marker='o', c='r', label = 'Actual Values')
plt.title("Housing prices")
plt.xlabel("Size (in 1000 sqft)")
plt.ylabel("Price (in 1000s of dollars)")
plt.plot(x_train, tmp_f_wb, c='b', label = 'Our prediction')
plt.legend()
plt.show()
# Out:
# printing np zeros array : f_wb initial values [0. 0.]
# tmp_f_wb : [300. 500.]

# %%
x_i = 1.2
cost_1200sqft = x_i * w + b
print(f"our prediction for cost of 1200 sqft house is {cost_1200sqft:.0f} thousand dollars")
# Out:
# our prediction for cost of 1200 sqft house is 340 thousand dollars
